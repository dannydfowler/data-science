# %%
import pandas as pd
pd.options.display.max_rows = 4000
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns',100)

# %% [markdown]
# ## Introduction
# We have two exit surveys, one from  Department of Education, Training and Employment (DETE) and the other from the Technical and Further Education (TAFE) institute in Queensland.
#
# We are interested in the following questions:
# * Are employees who only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been there longer?
# * Are younger employees resigning due to some kind of dissatisfaction? What about older employees?

# %%
dete_survey = pd.read_csv('../My Datasets/dete-exit-survey-january-2014.csv')
tafe_survey = pd.read_csv('../My Datasets/tafe-employee-exit-survey-access-database-december-2013.csv', encoding='cp1252')

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
# ID                                     822 non-null int64
# SeparationType                         822 non-null object
# Cease Date                             822 non-null object
# DETE Start Date                        822 non-null object
# Role Start Date                        822 non-null object
# Position                               817 non-null object
# Classification                         455 non-null object
# Region                                 822 non-null object
# Business Unit                          126 non-null object
# Employment Status                      817 non-null object
# Career move to public sector           822 non-null bool
# Career move to private sector          822 non-null bool
# Interpersonal conflicts                822 non-null bool
# Job dissatisfaction                    822 non-null bool
# Dissatisfaction with the department    822 non-null bool
# Physical work environment              822 non-null bool
# Lack of recognition                    822 non-null bool
# Lack of job security                   822 non-null bool
# Work location                          822 non-null bool
# Employment conditions                  822 non-null bool
# Maternity/family                       822 non-null bool
# Relocation                             822 non-null bool
# Study/Travel                           822 non-null bool
# Ill Health                             822 non-null bool
# Traumatic incident                     822 non-null bool
# Work life balance                      822 non-null bool
# Workload                               822 non-null bool
# None of the above                      822 non-null bool
# Professional Development               808 non-null object
# Opportunities for promotion            735 non-null object
# Staff morale                           816 non-null object
# Workplace issue                        788 non-null object
# Physical environment                   817 non-null object
# Worklife balance                       815 non-null object
# Stress and pressure support            810 non-null object
# Performance of supervisor              813 non-null object
# Peer support                           812 non-null object
# Initiative                             813 non-null object
# Skills                                 811 non-null object
# Coach                                  767 non-null object
# Career Aspirations                     746 non-null object
# Feedback                               792 non-null object
# Further PD                             768 non-null object
# Communication                          814 non-null object
# My say                                 812 non-null object
# Information                            816 non-null object
# Kept informed                          813 non-null object
# Wellness programs                      766 non-null object
# Health & Safety                        793 non-null object
# Gender                                 798 non-null object
# Age                                    811 non-null object
# Aboriginal                             16 non-null object
# Torres Strait                          3 non-null object
# South Sea                              7 non-null object
# Disability                             23 non-null object
# NESB                                   32 non-null object
# dtypes: bool(18), int64(1), object(37)
# memory usage: 258.6+ KB

# %%
dete_survey.head(2)
# Out:
#    ID                    SeparationType Cease Date DETE Start Date  \
# 0  1   Ill Health Retirement             08/2012    1984
# 1  2   Voluntary Early Retirement (VER)  08/2012    Not Stated
#
#   Role Start Date        Position Classification          Region  \
# 0  2004            Public Servant  A01-A04        Central Office
# 1  Not Stated      Public Servant  AO5-AO7        Central Office
#
#                        Business Unit    Employment Status  \
# 0  Corporate Strategy and Peformance  Permanent Full-time
# 1  Corporate Strategy and Peformance  Permanent Full-time
#
#    Career move to public sector  Career move to private sector  \
# 0  True                          False
# 1  False                         False
#
#    Interpersonal conflicts  Job dissatisfaction  \
# 0  False                    True
# 1  False                    False
#
#    Dissatisfaction with the department  Physical work environment  \
# 0  False                                False
# 1  False                                False
#
#    Lack of recognition  Lack of job security  Work location  \
# 0  True                 False                 False
# 1  False                False                 False
#
#    Employment conditions  Maternity/family  Relocation  Study/Travel  \
# 0  False                  False             False       False
# 1  False                  False             False       False
#
#    Ill Health  Traumatic incident  Work life balance  Workload  \
# 0  False       False               False              False
# 1  False       False               False              False
#
#    None of the above Professional Development Opportunities for promotion  \
# 0  True               A                        A
# 1  False              A                        A
#
#   Staff morale Workplace issue Physical environment Worklife balance  \
# 0  N            N               N                    A
# 1  N            N               N                    N
#
#   Stress and pressure support Performance of supervisor Peer support  \
# 0  A                           A                         A
# 1  A                           A                         A
#
#   Initiative Skills Coach Career Aspirations Feedback Further PD  \
# 0  N          N      N     A                  A        A
# 1  N          N      N     A                  A        A
#
#   Communication My say Information Kept informed Wellness programs  \
# 0  N             A      A           N             N
# 1  N             A      A           N             N
#
#   Health & Safety Gender    Age Aboriginal Torres Strait South Sea Disability  \
# 0  N               Male   56-60  NaN        NaN           NaN       NaN
# 1  N               Male   56-60  NaN        NaN           NaN       NaN
#
#   NESB
# 0  Yes
# 1  NaN

# %% [markdown]
# We can see that the Dete Start Date can contain a 'Not Stated' value, which should be recognised as a missing value. We also observe that the format for Cease Date is not consistent.

# %%
dete_survey = pd.read_csv('../My Datasets/dete-exit-survey-january-2014.csv',na_values='Not Stated')

# %%
dete_survey.head(2)
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0  1   Ill Health Retirement             08/2012    1984.0
# 1  2   Voluntary Early Retirement (VER)  08/2012   NaN
#
#    Role Start Date        Position Classification          Region  \
# 0  2004.0           Public Servant  A01-A04        Central Office
# 1 NaN               Public Servant  AO5-AO7        Central Office
#
#                        Business Unit    Employment Status  \
# 0  Corporate Strategy and Peformance  Permanent Full-time
# 1  Corporate Strategy and Peformance  Permanent Full-time
#
#    Career move to public sector  Career move to private sector  \
# 0  True                          False
# 1  False                         False
#
#    Interpersonal conflicts  Job dissatisfaction  \
# 0  False                    True
# 1  False                    False
#
#    Dissatisfaction with the department  Physical work environment  \
# 0  False                                False
# 1  False                                False
#
#    Lack of recognition  Lack of job security  Work location  \
# 0  True                 False                 False
# 1  False                False                 False
#
#    Employment conditions  Maternity/family  Relocation  Study/Travel  \
# 0  False                  False             False       False
# 1  False                  False             False       False
#
#    Ill Health  Traumatic incident  Work life balance  Workload  \
# 0  False       False               False              False
# 1  False       False               False              False
#
#    None of the above Professional Development Opportunities for promotion  \
# 0  True               A                        A
# 1  False              A                        A
#
#   Staff morale Workplace issue Physical environment Worklife balance  \
# 0  N            N               N                    A
# 1  N            N               N                    N
#
#   Stress and pressure support Performance of supervisor Peer support  \
# 0  A                           A                         A
# 1  A                           A                         A
#
#   Initiative Skills Coach Career Aspirations Feedback Further PD  \
# 0  N          N      N     A                  A        A
# 1  N          N      N     A                  A        A
#
#   Communication My say Information Kept informed Wellness programs  \
# 0  N             A      A           N             N
# 1  N             A      A           N             N
#
#   Health & Safety Gender    Age Aboriginal Torres Strait South Sea Disability  \
# 0  N               Male   56-60  NaN        NaN           NaN       NaN
# 1  N               Male   56-60  NaN        NaN           NaN       NaN
#
#   NESB
# 0  Yes
# 1  NaN

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
# ID                                     822 non-null int64
# SeparationType                         822 non-null object
# Cease Date                             788 non-null object
# DETE Start Date                        749 non-null float64
# Role Start Date                        724 non-null float64
# Position                               817 non-null object
# Classification                         455 non-null object
# Region                                 717 non-null object
# Business Unit                          126 non-null object
# Employment Status                      817 non-null object
# Career move to public sector           822 non-null bool
# Career move to private sector          822 non-null bool
# Interpersonal conflicts                822 non-null bool
# Job dissatisfaction                    822 non-null bool
# Dissatisfaction with the department    822 non-null bool
# Physical work environment              822 non-null bool
# Lack of recognition                    822 non-null bool
# Lack of job security                   822 non-null bool
# Work location                          822 non-null bool
# Employment conditions                  822 non-null bool
# Maternity/family                       822 non-null bool
# Relocation                             822 non-null bool
# Study/Travel                           822 non-null bool
# Ill Health                             822 non-null bool
# Traumatic incident                     822 non-null bool
# Work life balance                      822 non-null bool
# Workload                               822 non-null bool
# None of the above                      822 non-null bool
# Professional Development               808 non-null object
# Opportunities for promotion            735 non-null object
# Staff morale                           816 non-null object
# Workplace issue                        788 non-null object
# Physical environment                   817 non-null object
# Worklife balance                       815 non-null object
# Stress and pressure support            810 non-null object
# Performance of supervisor              813 non-null object
# Peer support                           812 non-null object
# Initiative                             813 non-null object
# Skills                                 811 non-null object
# Coach                                  767 non-null object
# Career Aspirations                     746 non-null object
# Feedback                               792 non-null object
# Further PD                             768 non-null object
# Communication                          814 non-null object
# My say                                 812 non-null object
# Information                            816 non-null object
# Kept informed                          813 non-null object
# Wellness programs                      766 non-null object
# Health & Safety                        793 non-null object
# Gender                                 798 non-null object
# Age                                    811 non-null object
# Aboriginal                             16 non-null object
# Torres Strait                          3 non-null object
# South Sea                              7 non-null object
# Disability                             23 non-null object
# NESB                                   32 non-null object
# dtypes: bool(18), float64(2), int64(1), object(35)
# memory usage: 258.6+ KB

# %%
tafe_survey.head(3)
# Out:
#             Record ID                              Institute  \
# 0  634133009996094000  Southern Queensland Institute of TAFE
# 1  634133654064531000  Mount Isa Institute of TAFE
# 2  634138845606563000  Mount Isa Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)  2010.0          Contract Expired
# 1  Non-Delivery (corporate)  2010.0          Retirement
# 2  Delivery (teaching)       2010.0          Retirement
#
#   Contributing Factors. Career Move - Public Sector   \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 0  NaN                              NaN
# 1  -                                -
# 2  -                                -
#
#   Contributing Factors. Dissatisfaction  \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Job Dissatisfaction  \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Interpersonal Conflict Contributing Factors. Study  \
# 0  NaN                                          NaN
# 1  -                                            -
# 2  -                                            -
#
#   Contributing Factors. Travel Contributing Factors. Other  \
# 0  NaN                          NaN
# 1  Travel                       -
# 2  -                            -
#
#   Contributing Factors. NONE  \
# 0  NaN
# 1  -
# 2  NONE
#
#   Main Factor.     Which of these was the main factor for leaving?  \
# 0  NaN
# 1  NaN
# 2  NaN
#
#   InstituteViews. Topic:1. I feel the senior leadership had a clear vision and direction  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   InstituteViews. Topic:2. I was given access to skills training to help me do my job better  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   InstituteViews. Topic:3. I was given adequate opportunities for personal development  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   InstituteViews. Topic:4. I was given adequate opportunities for promotion within %Institute]Q25LBL%  \
# 0  Neutral
# 1  Agree
# 2  Agree
#
#   InstituteViews. Topic:5. I felt the salary for the job was right for the responsibilities I had  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   InstituteViews. Topic:6. The organisation recognised when staff did good work  \
# 0  Agree
# 1  Strongly Agree
# 2  Agree
#
#   InstituteViews. Topic:7. Management was generally supportive of me  \
# 0  Agree
# 1  Strongly Agree
# 2  Strongly Agree
#
#   InstituteViews. Topic:8. Management was generally supportive of my team  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   InstituteViews. Topic:9. I was kept informed of the changes in the organisation which would affect me  \
# 0  Agree
# 1  Strongly Agree
# 2  Agree
#
#   InstituteViews. Topic:10. Staff morale was positive within the Institute  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   InstituteViews. Topic:11. If I had a workplace issue it was dealt with quickly  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   InstituteViews. Topic:12. If I had a workplace issue it was dealt with efficiently  \
# 0  Agree
# 1  Agree
# 2  Neutral
#
#   InstituteViews. Topic:13. If I had a workplace issue it was dealt with discreetly  \
# 0  Agree
# 1  Disagree
# 2  Neutral
#
#   WorkUnitViews. Topic:14. I was satisfied with the quality of the management and supervision within my work unit  \
# 0  Agree
# 1  Strongly Agree
# 2  Strongly Agree
#
#   WorkUnitViews. Topic:15. I worked well with my colleagues  \
# 0  Agree
# 1  Strongly Agree
# 2  Strongly Agree
#
#   WorkUnitViews. Topic:16. My job was challenging and interesting  \
# 0  Agree
# 1  Strongly Agree
# 2  Agree
#
#   WorkUnitViews. Topic:17. I was encouraged to use my initiative in the course of my work  \
# 0  Strongly Agree
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:18. I had sufficient contact with other people in my job  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:19. I was given adequate support and co-operation by my peers to enable me to do my job  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:20. I was able to use the full range of my skills in my job  \
# 0  Agree
# 1  Strongly Agree
# 2  Agree
#
#   WorkUnitViews. Topic:21. I was able to use the full range of my abilities in my job. ; Category:Level of Agreement; Question:YOUR VIEWS ABOUT YOUR WORK UNIT]  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:22. I was able to use the full range of my knowledge in my job  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:23. My job provided sufficient variety  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:24. I was able to cope with the level of stress and pressure in my job  \
# 0  Agree
# 1  Strongly Agree
# 2  Agree
#
#   WorkUnitViews. Topic:25. My job allowed me to balance the demands of work and family to my satisfaction  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:26. My supervisor gave me adequate personal recognition and feedback on my performance  \
# 0  Agree
# 1  Strongly Agree
# 2  Agree
#
#   WorkUnitViews. Topic:27. My working environment was satisfactory e.g. sufficient space, good lighting, suitable seating and working area  \
# 0  Agree
# 1  Strongly Agree
# 2  Agree
#
#   WorkUnitViews. Topic:28. I was given the opportunity to mentor and coach others in order for me to pass on my skills and knowledge prior to my cessation date  \
# 0  Neutral
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:29. There was adequate communication between staff in my unit  \
# 0  Agree
# 1  Agree
# 2  Agree
#
#   WorkUnitViews. Topic:30. Staff morale was positive within my work unit  \
# 0  Agree
# 1  Strongly Agree
# 2  Agree
#
#   Induction. Did you undertake Workplace Induction?  \
# 0  Yes
# 1  No
# 2  No
#
#   InductionInfo. Topic:Did you undertake a Corporate Induction?  \
# 0  Yes
# 1  NaN
# 2  NaN
#
#   InductionInfo. Topic:Did you undertake a Institute Induction?  \
# 0  Yes
# 1  NaN
# 2  NaN
#
#   InductionInfo. Topic: Did you undertake Team Induction?  \
# 0  Yes
# 1  NaN
# 2  NaN
#
#   InductionInfo. Face to Face Topic:Did you undertake a Corporate Induction; Category:How it was conducted?  \
# 0  Face to Face
# 1  NaN
# 2  NaN
#
#   InductionInfo. On-line Topic:Did you undertake a Corporate Induction; Category:How it was conducted?  \
# 0  -
# 1  NaN
# 2  NaN
#
#   InductionInfo. Induction Manual Topic:Did you undertake a Corporate Induction?  \
# 0  -
# 1  NaN
# 2  NaN
#
#   InductionInfo. Face to Face Topic:Did you undertake a Institute Induction?  \
# 0  Face to Face
# 1  NaN
# 2  NaN
#
#   InductionInfo. On-line Topic:Did you undertake a Institute Induction?  \
# 0  -
# 1  NaN
# 2  NaN
#
#   InductionInfo. Induction Manual Topic:Did you undertake a Institute Induction?  \
# 0  -
# 1  NaN
# 2  NaN
#
#   InductionInfo. Face to Face Topic: Did you undertake Team Induction; Category?  \
# 0  Face to Face
# 1  NaN
# 2  NaN
#
#   InductionInfo. On-line Topic: Did you undertake Team Induction?process you undertook and how it was conducted.]  \
# 0  -
# 1  NaN
# 2  NaN
#
#   InductionInfo. Induction Manual Topic: Did you undertake Team Induction?  \
# 0  -
# 1  NaN
# 2  NaN
#
#   Workplace. Topic:Did you and your Manager develop a Performance and Professional Development Plan (PPDP)?  \
# 0  Yes
# 1  Yes
# 2  Yes
#
#   Workplace. Topic:Does your workplace promote a work culture free from all forms of unlawful discrimination?  \
# 0  Yes
# 1  Yes
# 2  Yes
#
#   Workplace. Topic:Does your workplace promote and practice the principles of employment equity?  \
# 0  Yes
# 1  Yes
# 2  Yes
#
#   Workplace. Topic:Does your workplace value the diversity of its employees?  \
# 0  Yes
# 1  Yes
# 2  Yes
#
#   Workplace. Topic:Would you recommend the Institute as an employer to others?  \
# 0  Yes
# 1  Yes
# 2  Yes
#
#   Gender.     What is your Gender? CurrentAge.     Current Age  \
# 0  Female                           26 – 30
# 1  NaN                              NaN
# 2  NaN                              NaN
#
#   Employment Type.     Employment Type Classification.     Classification  \
# 0  Temporary Full-time                  Administration (AO)
# 1  NaN                                  NaN
# 2  NaN                                  NaN
#
#   LengthofServiceOverall. Overall Length of Service at Institute (in years)  \
# 0  1-2
# 1  NaN
# 2  NaN
#
#   LengthofServiceCurrent. Length of Service at current workplace (in years)
# 0  1-2
# 1  NaN
# 2  NaN

# %%
tafe_survey.columns[-3]
# Out:
# 'Classification. \xa0\xa0\xa0\xa0Classification'

# %% [markdown]
# Note there is a large proportion of missing values for the LengthOfServiceOverall column (approx 15%). We may be able to obtain this from elsewhere in the dataset.

# %% [markdown]
# Here we drop the irrelevant columns from both datasets:

# %%
dete_survey_updated = dete_survey.drop(dete_survey.columns[28:49], axis=1)

# %%
tafe_survey_updated = tafe_survey.drop(tafe_survey.columns[17:66],axis=1)

# %% [markdown]
# We have removed irrelevant columns from both data sets and marked values as missing in the dete dataset.

# %% [markdown]
# Now we want to standardise the naming of the columns:

# %%
dete_survey_updated.columns = dete_survey_updated.columns.str.lower().str.strip().str.replace(' ','_')

# %%
dete_survey_updated.columns
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %%
tafe_survey_updated.columns = tafe_survey_updated.columns.str.replace('\xa0','')

# %%
tafe_survey_updated.columns
# Out:
# Index(['Record ID', 'Institute', 'WorkArea', 'CESSATION YEAR',
#        'Reason for ceasing employment',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE',
#        'Gender. What is your Gender?', 'CurrentAge. Current Age',
#        'Employment Type. Employment Type', 'Classification. Classification',
#        'LengthofServiceOverall. Overall Length of Service at Institute (in years)',
#        'LengthofServiceCurrent. Length of Service at current workplace (in years)'],
#       dtype='object')

# %%
tafe_mapping = {
    'Record ID': 'id',
'CESSATION YEAR': 'cease_date',
'Reason for ceasing employment': 'separationtype',
'Gender. What is your Gender?': 'gender',
'CurrentAge. Current Age': 'age',
'Employment Type. Employment Type': 'employment_status',
'Classification. \xa0\xa0\xa0\xa0Classification': 'position',
'LengthofServiceOverall. Overall Length of Service at Institute (in years)': 'institute_service',
'LengthofServiceCurrent. Length of Service at current workplace (in years)': 'role_service'
}

# %%
tafe_survey_updated = tafe_survey_updated.rename(tafe_mapping,axis=1)

# %% [markdown]
# We have now renamed the relevant columns to be consistent across both datasets.

# %%
dete_survey_updated.head(3)
# Out:
#    id                    separationtype cease_date  dete_start_date  \
# 0  1   Ill Health Retirement             08/2012    1984.0
# 1  2   Voluntary Early Retirement (VER)  08/2012   NaN
# 2  3   Voluntary Early Retirement (VER)  05/2012    2011.0
#
#    role_start_date         position classification          region  \
# 0  2004.0           Public Servant   A01-A04        Central Office
# 1 NaN               Public Servant   AO5-AO7        Central Office
# 2  2011.0           Schools Officer  NaN            Central Office
#
#                        business_unit    employment_status  \
# 0  Corporate Strategy and Peformance  Permanent Full-time
# 1  Corporate Strategy and Peformance  Permanent Full-time
# 2  Education Queensland               Permanent Full-time
#
#    career_move_to_public_sector  career_move_to_private_sector  \
# 0  True                          False
# 1  False                         False
# 2  False                         False
#
#    interpersonal_conflicts  job_dissatisfaction  \
# 0  False                    True
# 1  False                    False
# 2  False                    False
#
#    dissatisfaction_with_the_department  physical_work_environment  \
# 0  False                                False
# 1  False                                False
# 2  False                                False
#
#    lack_of_recognition  lack_of_job_security  work_location  \
# 0  True                 False                 False
# 1  False                False                 False
# 2  False                False                 False
#
#    employment_conditions  maternity/family  relocation  study/travel  \
# 0  False                  False             False       False
# 1  False                  False             False       False
# 2  False                  False             False       False
#
#    ill_health  traumatic_incident  work_life_balance  workload  \
# 0  False       False               False              False
# 1  False       False               False              False
# 2  False       False               False              False
#
#    none_of_the_above gender          age aboriginal torres_strait south_sea  \
# 0  True               Male   56-60        NaN        NaN           NaN
# 1  False              Male   56-60        NaN        NaN           NaN
# 2  True               Male   61 or older  NaN        NaN           NaN
#
#   disability nesb
# 0  NaN        Yes
# 1  NaN        NaN
# 2  NaN        NaN

# %%
tafe_survey_updated.head(3)
# Out:
#                    id                              Institute  \
# 0  634133009996094000  Southern Queensland Institute of TAFE
# 1  634133654064531000  Mount Isa Institute of TAFE
# 2  634138845606563000  Mount Isa Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)  2010.0      Contract Expired
# 1  Non-Delivery (corporate)  2010.0      Retirement
# 2  Delivery (teaching)       2010.0      Retirement
#
#   Contributing Factors. Career Move - Public Sector   \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 0  NaN                              NaN
# 1  -                                -
# 2  -                                -
#
#   Contributing Factors. Dissatisfaction  \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Job Dissatisfaction  \
# 0  NaN
# 1  -
# 2  -
#
#   Contributing Factors. Interpersonal Conflict Contributing Factors. Study  \
# 0  NaN                                          NaN
# 1  -                                            -
# 2  -                                            -
#
#   Contributing Factors. Travel Contributing Factors. Other  \
# 0  NaN                          NaN
# 1  Travel                       -
# 2  -                            -
#
#   Contributing Factors. NONE  gender      age    employment_status  \
# 0  NaN                        Female  26 – 30  Temporary Full-time
# 1  -                          NaN     NaN      NaN
# 2  NONE                       NaN     NaN      NaN
#
#   Classification. Classification institute_service role_service
# 0  Administration (AO)            1-2               1-2
# 1  NaN                            NaN               NaN
# 2  NaN                            NaN               NaN

# %% [markdown]
# Now that we've renamed columns to be consistent, we will continue to remove columns that won't be used in the analysis.

# %% [markdown]
# Recall that the goal of this analysis is to answer the question:
# * Are employees who have only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been at the job longer?

# %%
dete_survey_updated['separationtype'].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer              91
# Resignation-Move overseas/interstate    70
# Voluntary Early Retirement (VER)        67
# Ill Health Retirement                   61
# Other                                   49
# Contract Expired                        34
# Termination                             15
# Name: separationtype, dtype: int64

# %%
tafe_survey_updated['separationtype'].value_counts(dropna=False)
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                  82
# Transfer                    25
# Termination                 23
# NaN                         1
# Name: separationtype, dtype: int64

# %% [markdown]
# Note that in the dete survey we have several resignation reasons, which are the rows we will be interested in.
#
# The tafe survey still contains na values, which we remove here (there is only one row).

# %%
tafe_survey_updated = tafe_survey_updated.dropna(subset=['separationtype'],axis=0)

# %%
dete_resignations = dete_survey_updated.loc[dete_survey_updated['separationtype'].str.contains('Resignation')].copy()

# %%
tafe_resignations=tafe_survey_updated.loc[tafe_survey_updated['separationtype']=='Resignation']

# %%
dete_resignations.head(3)
# Out:
#    id             separationtype cease_date  dete_start_date  role_start_date  \
# 3  4   Resignation-Other reasons  05/2012    2005.0           2006.0
# 5  6   Resignation-Other reasons  05/2012    1994.0           1997.0
# 8  9   Resignation-Other reasons  07/2012    2009.0           2009.0
#
#            position classification              region         business_unit  \
# 3  Teacher           Primary        Central Queensland  NaN
# 5  Guidance Officer  NaN            Central Office      Education Queensland
# 8  Teacher           Secondary      North Queensland    NaN
#
#      employment_status  career_move_to_public_sector  \
# 3  Permanent Full-time  False
# 5  Permanent Full-time  False
# 8  Permanent Full-time  False
#
#    career_move_to_private_sector  interpersonal_conflicts  \
# 3  True                           False
# 5  True                           False
# 8  True                           False
#
#    job_dissatisfaction  dissatisfaction_with_the_department  \
# 3  False                False
# 5  False                False
# 8  False                False
#
#    physical_work_environment  lack_of_recognition  lack_of_job_security  \
# 3  False                      False                False
# 5  False                      False                False
# 8  False                      False                False
#
#    work_location  employment_conditions  maternity/family  relocation  \
# 3  False          False                  False             False
# 5  False          True                   True              False
# 8  False          False                  False             False
#
#    study/travel  ill_health  traumatic_incident  work_life_balance  workload  \
# 3  False         False       False               False              False
# 5  False         False       False               False              False
# 8  False         False       False               False              False
#
#    none_of_the_above  gender    age aboriginal torres_strait south_sea  \
# 3  False              Female  36-40  NaN        NaN           NaN
# 5  False              Female  41-45  NaN        NaN           NaN
# 8  False              Female  31-35  NaN        NaN           NaN
#
#   disability nesb
# 3  NaN        NaN
# 5  NaN        NaN
# 8  NaN        NaN

# %%
tafe_resignations.head(3)
# Out:
#                    id                              Institute  \
# 3  634139903350000000  Mount Isa Institute of TAFE
# 4  634146578511788000  Southern Queensland Institute of TAFE
# 5  634147506906311000  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)  2010.0      Resignation
# 4  Delivery (teaching)       2010.0      Resignation
# 5  Delivery (teaching)       2010.0      Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3  -
# 4  -
# 5  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 3  -
# 4  Career Move - Private Sector
# 5  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 3  -
# 4  -
# 5  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 3  -                                -
# 4  -                                -
# 5  -                                -
#
#   Contributing Factors. Dissatisfaction  \
# 3  -
# 4  -
# 5  -
#
#   Contributing Factors. Job Dissatisfaction  \
# 3  -
# 4  -
# 5  -
#
#   Contributing Factors. Interpersonal Conflict Contributing Factors. Study  \
# 3  -                                            -
# 4  -                                            -
# 5  -                                            -
#
#   Contributing Factors. Travel Contributing Factors. Other  \
# 3  Travel                       -
# 4  -                            -
# 5  -                            Other
#
#   Contributing Factors. NONE  gender          age    employment_status  \
# 3  -                          NaN     NaN          NaN
# 4  -                          Male    41 – 45      Permanent Full-time
# 5  -                          Female  56 or older  Contract/casual
#
#   Classification. Classification institute_service role_service
# 3  NaN                            NaN               NaN
# 4  Teacher (including LVT)        3-4               3-4
# 5  Teacher (including LVT)        7-10              7-10

# %% [markdown]
# We are now left only with the individuals that resigned in each respective area.

# %% [markdown]
# ## Data Verification

# %% [markdown]
# We want to ensure that all of the cease dates take place before the start dates:

# %%
dete_resignations['cease_date'].value_counts()
# Out:
# 2012       126
# 2013       74
# 01/2014    22
# 12/2013    17
# 06/2013    14
# 09/2013    11
# 11/2013    9
# 07/2013    9
# 10/2013    6
# 08/2013    4
# 05/2012    2
# 05/2013    2
# 07/2012    1
# 09/2010    1
# 07/2006    1
# 2010       1
# Name: cease_date, dtype: int64

# %% [markdown]
# We will convert the cease date to a cease year column.

# %%
dete_resignations['cease_date'] = dete_resignations['cease_date'].str.replace(r'[0-9][0-9]/','').astype('float')

# %%
a = dete_resignations['cease_date'] < dete_resignations['dete_start_date']
a.sum()
# Out:
# 0

# %% [markdown]
# All of the cease dates are after the start dates in the dete data.

# %%
dete_resignations['cease_date'].value_counts().sort_index()
# Out:
# 2006.0    1
# 2010.0    2
# 2012.0    129
# 2013.0    146
# 2014.0    22
# Name: cease_date, dtype: int64

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting start and cease dates

# %%
fig, ((ax1, ax2,ax3)) = plt.subplots(nrows=1, ncols=3, sharex=False, sharey=True, figsize=(10,5))
dete_resignations['dete_start_date'].plot(kind='box',ax=ax1)
dete_resignations['cease_date'].plot(kind='box',ax=ax2,label='dete_cease_date')
tafe_resignations['cease_date'].plot(kind='box',ax=ax3, label='tafe_cease_date')

# %% [markdown]
# There appear to be no issues regarding the years. We can also check on a row level:

# %%
(dete_resignations['dete_start_date'] > dete_resignations['cease_date']).sum()
# Out:
# 0

# %% [markdown]
# This tells us there are no start dates that are after the cease date for the dete data.

# %% [markdown]
# ### Comparing Lengths of Service

# %% [markdown]
# We will create a service length column for the dete data as we have start and end dates for each row. This will align the data with the tafe survey data.

# %%
dete_resignations['institute_service'] = dete_resignations['cease_date']-dete_resignations['dete_start_date']

# %%
dete_resignations.head(3)
# Out:
#    id             separationtype  cease_date  dete_start_date  \
# 3  4   Resignation-Other reasons  2012.0      2005.0
# 5  6   Resignation-Other reasons  2012.0      1994.0
# 8  9   Resignation-Other reasons  2012.0      2009.0
#
#    role_start_date          position classification              region  \
# 3  2006.0           Teacher           Primary        Central Queensland
# 5  1997.0           Guidance Officer  NaN            Central Office
# 8  2009.0           Teacher           Secondary      North Queensland
#
#           business_unit    employment_status  career_move_to_public_sector  \
# 3  NaN                   Permanent Full-time  False
# 5  Education Queensland  Permanent Full-time  False
# 8  NaN                   Permanent Full-time  False
#
#    career_move_to_private_sector  interpersonal_conflicts  \
# 3  True                           False
# 5  True                           False
# 8  True                           False
#
#    job_dissatisfaction  dissatisfaction_with_the_department  \
# 3  False                False
# 5  False                False
# 8  False                False
#
#    physical_work_environment  lack_of_recognition  lack_of_job_security  \
# 3  False                      False                False
# 5  False                      False                False
# 8  False                      False                False
#
#    work_location  employment_conditions  maternity/family  relocation  \
# 3  False          False                  False             False
# 5  False          True                   True              False
# 8  False          False                  False             False
#
#    study/travel  ill_health  traumatic_incident  work_life_balance  workload  \
# 3  False         False       False               False              False
# 5  False         False       False               False              False
# 8  False         False       False               False              False
#
#    none_of_the_above  gender    age aboriginal torres_strait south_sea  \
# 3  False              Female  36-40  NaN        NaN           NaN
# 5  False              Female  41-45  NaN        NaN           NaN
# 8  False              Female  31-35  NaN        NaN           NaN
#
#   disability nesb  institute_service
# 3  NaN        NaN  7.0
# 5  NaN        NaN  18.0
# 8  NaN        NaN  3.0

# %% [markdown]
# ### Identifying Dissatisfied Employees

# %%
dete_resignations['dissatisfied'] = dete_resignations[['job_dissatisfaction',
'dissatisfaction_with_the_department',
'physical_work_environment',
'lack_of_recognition',
'lack_of_job_security',
'work_location',
'employment_conditions',
'work_life_balance',
'workload']].any(axis=1,skipna=False)

# %%
tafe_resignations.head(2)
# Out:
#                    id                              Institute  \
# 3  634139903350000000  Mount Isa Institute of TAFE
# 4  634146578511788000  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)  2010.0      Resignation
# 4  Delivery (teaching)       2010.0      Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3  -
# 4  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 3  -
# 4  Career Move - Private Sector
#
#   Contributing Factors. Career Move - Self-employment  \
# 3  -
# 4  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 3  -                                -
# 4  -                                -
#
#   Contributing Factors. Dissatisfaction  \
# 3  -
# 4  -
#
#   Contributing Factors. Job Dissatisfaction  \
# 3  -
# 4  -
#
#   Contributing Factors. Interpersonal Conflict Contributing Factors. Study  \
# 3  -                                            -
# 4  -                                            -
#
#   Contributing Factors. Travel Contributing Factors. Other  \
# 3  Travel                       -
# 4  -                            -
#
#   Contributing Factors. NONE gender      age    employment_status  \
# 3  -                          NaN    NaN      NaN
# 4  -                          Male   41 – 45  Permanent Full-time
#
#   Classification. Classification institute_service role_service
# 3  NaN                            NaN               NaN
# 4  Teacher (including LVT)        3-4               3-4

# %%
import numpy as np

# %%
def update_vals(val):
    if pd.isnull(val):
        return np.nan
    elif val == '-':
        return False
    else:
        return True

# %%
# tafe_resignations['Contributing Factors. Dissatisfaction'] = tafe_resignations['Contributing Factors. Dissatisfaction'].apply(update_vals)

# %%
tafe_resignations[['Contributing Factors. Dissatisfaction','Contributing Factors. Job Dissatisfaction']] = tafe_resignations[['Contributing Factors. Dissatisfaction','Contributing Factors. Job Dissatisfaction']].applymap(update_vals)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:3489: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
tafe_resignations['dissatisfied'] = tafe_resignations[['Contributing Factors. Dissatisfaction','Contributing Factors. Job Dissatisfaction']].any(axis=1,skipna=False)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tafe_resignations.head(5)
# Out:
#                    id                              Institute  \
# 3  634139903350000000  Mount Isa Institute of TAFE
# 4  634146578511788000  Southern Queensland Institute of TAFE
# 5  634147506906311000  Southern Queensland Institute of TAFE
# 6  634152007975694000  Barrier Reef Institute of TAFE
# 7  634153745310374000  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date separationtype  \
# 3  Non-Delivery (corporate)  2010.0      Resignation
# 4  Delivery (teaching)       2010.0      Resignation
# 5  Delivery (teaching)       2010.0      Resignation
# 6  Non-Delivery (corporate)  2010.0      Resignation
# 7  Delivery (teaching)       2010.0      Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 3  -
# 4  -
# 5  -
# 6  -
# 7  -
#
#   Contributing Factors. Career Move - Private Sector   \
# 3  -
# 4  Career Move - Private Sector
# 5  -
# 6  Career Move - Private Sector
# 7  -
#
#   Contributing Factors. Career Move - Self-employment  \
# 3  -
# 4  -
# 5  -
# 6  -
# 7  -
#
#   Contributing Factors. Ill Health Contributing Factors. Maternity/Family  \
# 3  -                                -
# 4  -                                -
# 5  -                                -
# 6  -                                Maternity/Family
# 7  -                                -
#
#   Contributing Factors. Dissatisfaction  \
# 3  False
# 4  False
# 5  False
# 6  False
# 7  False
#
#   Contributing Factors. Job Dissatisfaction  \
# 3  False
# 4  False
# 5  False
# 6  False
# 7  False
#
#   Contributing Factors. Interpersonal Conflict Contributing Factors. Study  \
# 3  -                                            -
# 4  -                                            -
# 5  -                                            -
# 6  -                                            -
# 7  -                                            -
#
#   Contributing Factors. Travel Contributing Factors. Other  \
# 3  Travel                       -
# 4  -                            -
# 5  -                            Other
# 6  -                            Other
# 7  -                            Other
#
#   Contributing Factors. NONE  gender            age    employment_status  \
# 3  -                          NaN     NaN            NaN
# 4  -                          Male    41 – 45        Permanent Full-time
# 5  -                          Female  56 or older    Contract/casual
# 6  -                          Male    20 or younger  Temporary Full-time
# 7  -                          Male    46 – 50        Permanent Full-time
#
#   Classification. Classification institute_service role_service dissatisfied
# 3  NaN                            NaN               NaN          False
# 4  Teacher (including LVT)        3-4               3-4          False
# 5  Teacher (including LVT)        7-10              7-10         False
# 6  Administration (AO)            3-4               3-4          False
# 7  Teacher (including LVT)        3-4               3-4          False

# %%
dete_resignations_up = dete_resignations.copy()
tafe_resignations_up = tafe_resignations.copy()

# %% [markdown]
# We have changed the values in the tefe data to reflect True, False or NaN for the responses given to these two columns, which represent a 'dissatisfaction reason'.
#
# This change has allowed us to add a 'dissatisfied' column to both datasets, which allows us to show for any employee whether they left for a dissatisfaction reason, did not, or did not answer.

# %%
dete_resignations_up.head(3)
# Out:
#    id             separationtype  cease_date  dete_start_date  \
# 3  4   Resignation-Other reasons  2012.0      2005.0
# 5  6   Resignation-Other reasons  2012.0      1994.0
# 8  9   Resignation-Other reasons  2012.0      2009.0
#
#    role_start_date          position classification              region  \
# 3  2006.0           Teacher           Primary        Central Queensland
# 5  1997.0           Guidance Officer  NaN            Central Office
# 8  2009.0           Teacher           Secondary      North Queensland
#
#           business_unit    employment_status  career_move_to_public_sector  \
# 3  NaN                   Permanent Full-time  False
# 5  Education Queensland  Permanent Full-time  False
# 8  NaN                   Permanent Full-time  False
#
#    career_move_to_private_sector  interpersonal_conflicts  \
# 3  True                           False
# 5  True                           False
# 8  True                           False
#
#    job_dissatisfaction  dissatisfaction_with_the_department  \
# 3  False                False
# 5  False                False
# 8  False                False
#
#    physical_work_environment  lack_of_recognition  lack_of_job_security  \
# 3  False                      False                False
# 5  False                      False                False
# 8  False                      False                False
#
#    work_location  employment_conditions  maternity/family  relocation  \
# 3  False          False                  False             False
# 5  False          True                   True              False
# 8  False          False                  False             False
#
#    study/travel  ill_health  traumatic_incident  work_life_balance  workload  \
# 3  False         False       False               False              False
# 5  False         False       False               False              False
# 8  False         False       False               False              False
#
#    none_of_the_above  gender    age aboriginal torres_strait south_sea  \
# 3  False              Female  36-40  NaN        NaN           NaN
# 5  False              Female  41-45  NaN        NaN           NaN
# 8  False              Female  31-35  NaN        NaN           NaN
#
#   disability nesb  institute_service  dissatisfied
# 3  NaN        NaN  7.0                False
# 5  NaN        NaN  18.0               True
# 8  NaN        NaN  3.0                False

# %% [markdown]
# ### Combining Datasets

# %%
dete_resignations_up['institute'] = 'DETE'
tafe_resignations_up['institute'] = 'TAFE'

# %%
len(dete_resignations_up.columns)
# Out:
# 38

# %%
len(tafe_resignations_up.columns)
# Out:
# 25

# %%
combined = pd.concat([dete_resignations_up,tafe_resignations_up],axis=0,sort=True)

# %%
combined.head(10)
# Out:
#    Classification. Classification  \
# 3   NaN
# 5   NaN
# 8   NaN
# 9   NaN
# 11  NaN
# 12  NaN
# 14  NaN
# 16  NaN
# 20  NaN
# 21  NaN
#
#    Contributing Factors. Career Move - Private Sector   \
# 3   NaN
# 5   NaN
# 8   NaN
# 9   NaN
# 11  NaN
# 12  NaN
# 14  NaN
# 16  NaN
# 20  NaN
# 21  NaN
#
#    Contributing Factors. Career Move - Public Sector   \
# 3   NaN
# 5   NaN
# 8   NaN
# 9   NaN
# 11  NaN
# 12  NaN
# 14  NaN
# 16  NaN
# 20  NaN
# 21  NaN
#
#    Contributing Factors. Career Move - Self-employment  \
# 3   NaN
# 5   NaN
# 8   NaN
# 9   NaN
# 11  NaN
# 12  NaN
# 14  NaN
# 16  NaN
# 20  NaN
# 21  NaN
#
#    Contributing Factors. Dissatisfaction Contributing Factors. Ill Health  \
# 3   NaN                                   NaN
# 5   NaN                                   NaN
# 8   NaN                                   NaN
# 9   NaN                                   NaN
# 11  NaN                                   NaN
# 12  NaN                                   NaN
# 14  NaN                                   NaN
# 16  NaN                                   NaN
# 20  NaN                                   NaN
# 21  NaN                                   NaN
#
#    Contributing Factors. Interpersonal Conflict  \
# 3   NaN
# 5   NaN
# 8   NaN
# 9   NaN
# 11  NaN
# 12  NaN
# 14  NaN
# 16  NaN
# 20  NaN
# 21  NaN
#
#    Contributing Factors. Job Dissatisfaction  \
# 3   NaN
# 5   NaN
# 8   NaN
# 9   NaN
# 11  NaN
# 12  NaN
# 14  NaN
# 16  NaN
# 20  NaN
# 21  NaN
#
#    Contributing Factors. Maternity/Family Contributing Factors. NONE  \
# 3   NaN                                    NaN
# 5   NaN                                    NaN
# 8   NaN                                    NaN
# 9   NaN                                    NaN
# 11  NaN                                    NaN
# 12  NaN                                    NaN
# 14  NaN                                    NaN
# 16  NaN                                    NaN
# 20  NaN                                    NaN
# 21  NaN                                    NaN
#
#    Contributing Factors. Other Contributing Factors. Study  \
# 3   NaN                         NaN
# 5   NaN                         NaN
# 8   NaN                         NaN
# 9   NaN                         NaN
# 11  NaN                         NaN
# 12  NaN                         NaN
# 14  NaN                         NaN
# 16  NaN                         NaN
# 20  NaN                         NaN
# 21  NaN                         NaN
#
#    Contributing Factors. Travel Institute WorkArea aboriginal          age  \
# 3   NaN                          NaN       NaN      NaN        36-40
# 5   NaN                          NaN       NaN      NaN        41-45
# 8   NaN                          NaN       NaN      NaN        31-35
# 9   NaN                          NaN       NaN      NaN        46-50
# 11  NaN                          NaN       NaN      NaN        31-35
# 12  NaN                          NaN       NaN      NaN        36-40
# 14  NaN                          NaN       NaN      NaN        31-35
# 16  NaN                          NaN       NaN      NaN        61 or older
# 20  NaN                          NaN       NaN      NaN        56-60
# 21  NaN                          NaN       NaN      NaN        51-55
#
#            business_unit career_move_to_private_sector  \
# 3   NaN                   True
# 5   Education Queensland  True
# 8   NaN                   True
# 9   NaN                   False
# 11  NaN                   False
# 12  NaN                   False
# 14  NaN                   False
# 16  NaN                   False
# 20  NaN                   False
# 21  NaN                   False
#
#    career_move_to_public_sector  cease_date classification  dete_start_date  \
# 3   False                        2012.0      Primary        2005.0
# 5   False                        2012.0      NaN            1994.0
# 8   False                        2012.0      Secondary      2009.0
# 9   False                        2012.0      NaN            1997.0
# 11  False                        2012.0      Secondary      2009.0
# 12  False                        2012.0      Primary        1998.0
# 14  False                        2012.0      Secondary      2007.0
# 16  False                        2012.0      NaN           NaN
# 20  False                        2012.0      Secondary      1982.0
# 21  False                        2012.0      NaN            1980.0
#
#    disability dissatisfaction_with_the_department dissatisfied  \
# 3   NaN        False                               False
# 5   NaN        False                               True
# 8   NaN        False                               False
# 9   NaN        True                                True
# 11  NaN        False                               False
# 12  NaN        False                               False
# 14  NaN        True                                True
# 16  NaN        False                               True
# 20  NaN        False                               False
# 21  NaN        False                               False
#
#    employment_conditions    employment_status  gender  id ill_health  \
# 3   False                 Permanent Full-time  Female  4   False
# 5   True                  Permanent Full-time  Female  6   False
# 8   False                 Permanent Full-time  Female  9   False
# 9   False                 Permanent Part-time  Female  10  False
# 11  False                 Permanent Full-time  Male    12  False
# 12  False                 Permanent Full-time  Female  13  False
# 14  False                 Permanent Full-time  Male    15  False
# 16  False                 Permanent Part-time  Male    17  False
# 20  False                 Permanent Full-time  Male    21  False
# 21  False                 Permanent Part-time  Female  22  False
#
#    institute institute_service interpersonal_conflicts job_dissatisfaction  \
# 3   DETE      7                 False                   False
# 5   DETE      18                False                   False
# 8   DETE      3                 False                   False
# 9   DETE      15                True                    True
# 11  DETE      3                 False                   False
# 12  DETE      14                False                   False
# 14  DETE      5                 False                   True
# 16  DETE      NaN               False                   False
# 20  DETE      30                False                   False
# 21  DETE      32                True                    False
#
#    lack_of_job_security lack_of_recognition maternity/family nesb  \
# 3   False                False               False            NaN
# 5   False                False               True             NaN
# 8   False                False               False            NaN
# 9   False                False               False            NaN
# 11  False                False               True             NaN
# 12  False                False               True             NaN
# 14  False                False               False            NaN
# 16  False                True                False            NaN
# 20  False                False               False            NaN
# 21  False                False               False            NaN
#
#    none_of_the_above physical_work_environment          position  \
# 3   False             False                     Teacher
# 5   False             False                     Guidance Officer
# 8   False             False                     Teacher
# 9   False             False                     Teacher Aide
# 11  False             False                     Teacher
# 12  False             False                     Teacher
# 14  False             False                     Teacher
# 16  False             False                     Teacher Aide
# 20  True              False                     Teacher
# 21  False             False                     Cleaner
#
#                       region relocation role_service  role_start_date  \
# 3   Central Queensland        False      NaN          2006.0
# 5   Central Office            False      NaN          1997.0
# 8   North Queensland          False      NaN          2009.0
# 9   NaN                       False      NaN          2008.0
# 11  Far North Queensland      True       NaN          2009.0
# 12  Far North Queensland      False      NaN          1998.0
# 14  Central Queensland        False      NaN          2010.0
# 16  South East                True       NaN         NaN
# 20  Central Queensland        False      NaN          1982.0
# 21  Darling Downs South West  False      NaN          2009.0
#
#                           separationtype south_sea study/travel torres_strait  \
# 3   Resignation-Other reasons             NaN       False        NaN
# 5   Resignation-Other reasons             NaN       False        NaN
# 8   Resignation-Other reasons             NaN       False        NaN
# 9   Resignation-Other employer            NaN       False        NaN
# 11  Resignation-Move overseas/interstate  NaN       False        NaN
# 12  Resignation-Other reasons             NaN       False        NaN
# 14  Resignation-Other employer            NaN       False        NaN
# 16  Resignation-Other reasons             NaN       False        NaN
# 20  Resignation-Other employer            NaN       False        NaN
# 21  Resignation-Other reasons             NaN       False        NaN
#
#    traumatic_incident work_life_balance work_location workload
# 3   False              False             False         False
# 5   False              False             False         False
# 8   False              False             False         False
# 9   False              False             False         False
# 11  False              False             False         False
# 12  False              False             False         False
# 14  False              False             False         False
# 16  False              False             False         False
# 20  False              False             False         False
# 21  False              False             False         False

# %%
len(combined.columns)
# Out:
# 54

# %%
combined_updated = combined.dropna(axis=1,thresh=500)

# %% [markdown]
# Here we keep only the columns that have a significant amount of non-null values.

# %%
combined_updated['institute_service'] = combined_updated['institute_service'].astype('str').str.extract('([0-9]+)').astype('float')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def yearCat(val):
    if val is np.nan:
        return np.nan
    val = float(val)
    if 0 <= val < 3:
        return 'New'
    elif 3 <= val < 6:
        return 'Experienced'
    elif 7 <= val < 10:
        return 'Established'
    elif 11 <= val:
        return 'Veteran'

# %%
combined_updated['service_cat'] = combined_updated['institute_service'].apply(yearCat)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# We have categorised the length of service according to career stage, as recommended by this article: [link](https://www.businesswire.com/news/home/20171108006002/en/Age-Number-Engage-Employees-Career-Stage)

# %% [markdown]
# ### Initial Analysis

# %%
combined_updated['dissatisfied'].value_counts(dropna=False)
# Out:
# False    403
# True     240
# NaN      8
# Name: dissatisfied, dtype: int64

# %%
combined_updated['dissatisfied'] = combined_updated['dissatisfied'].fillna(False)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
service_pivot = combined_updated.pivot_table(index='service_cat',values='dissatisfied')

# %%
reorderlist = [ 'New', 'Established','Experienced' ,'Veteran']

# %%
# %matplotlib inline

# %%
service_pivot = service_pivot.reindex(reorderlist)

# %%
service_pivot.plot(kind='bar')

# %% [markdown]
# The visualisation of this plot suggests that dissatisfaction is more common for established employees or employees that have been at the institute the longest (the veterans).
